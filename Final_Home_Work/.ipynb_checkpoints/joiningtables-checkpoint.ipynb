# %%
import pandas as pd
import glob
import os

# %%
# reading two csv files
data1 = pd.read_csv('life-satisfaction-vs-life-expectancy.csv')
data2 = pd.read_csv('continents2.csv')

#using merge function by setting how='inner'
output1 = pd.merge(data1, data2,
on='Entity',
how='inner')

# displaying result
output1
#data1
output1.to_csv (r'/Users/voshananissanka/Desktop/Monash Third Year Semester 2/Data Visualization/Final_Home_Work/suicidecont.csv', index = False, header=True)

# %%
data3=pd.read_csv('suicidecont.csv')

# %%
data3
# Out:
#      Country name Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 5545     Zimbabwe  ZWE  2015
# 5546     Zimbabwe  ZWE  2016
# 5547     Zimbabwe  ZWE  2017
# 5548     Zimbabwe  ZWE  2018
# 5549     Zimbabwe  ZWE  2019
#
#       Deaths - Self-harm - Sex: Both - Age: All Ages (Percent)  \
# 0                                                  0.38
# 1                                                  0.39
# 2                                                  0.41
# 3                                                  0.42
# 4                                                  0.41
# ...                                                 ...
# 5545                                               1.68
# 5546                                               1.75
# 5547                                               1.80
# ...

# %%
data4=data3.groupby("year").count()

# %%
data4
# Out:
#       Country name  Life Ladder  Log GDP per capita  Social support  \
# year
# 2005            27           27                  27              27
# 2006            89           89                  88              89
# 2007           102          102                 102             100
# 2008           110          110                 110             110
# 2009           114          114                 113             113
# 2010           124          124                 123             120
# 2011           146          146                 145             145
# 2012           142          142                 140             142
# 2013           137          137                 136             137
# 2014           145          145                 142             142
# 2015           143          143                 140             142
# 2016           142          142                 139             142
# 2017           147          147                 146             146
# ...

# %%
whrlatlong=pd.read_csv("WHRlatlong.csv")

# %%
print(whrlatlong.groupby("year"))

# %%
whrlatlong
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1742     Zimbabwe  2016        3.735               7.984           0.768
# 1743     Zimbabwe  2017        3.638               8.016           0.754
# 1744     Zimbabwe  2018        3.616               8.049           0.775
# 1745     Zimbabwe  2019        2.694               7.950           0.759
# 1746     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...
